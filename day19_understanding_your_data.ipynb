# %% [markdown]
# # Question to be ask after seeing the data

# %%
import pandas as pd

# %%
df=pd.read_csv("dataset/Titanic-Dataset.csv")

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 629          630         0       3         O'Connell, Mr. Patrick D    male
# 238          239         0       2  Pengelly, Mr. Frederick William    male
# 777          778         1       3    Emanuel, Miss. Virginia Ethel  female
# 462          463         0       1                Gee, Mr. Arthur H    male
# 289          290         1       3             Connolly, Miss. Kate  female
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 629   NaN      0      0  334912   7.7333   NaN        Q
# 238  19.0      0      0   28665  10.5000   NaN        S
# 777   5.0      0      0  364516  12.4750   NaN        S
# 462  47.0      0      0  111320  38.5000   E63        S
# 289  22.0      0      0  370373   7.7500   NaN        Q

# %% [markdown]
# ## 1. How big is the data?

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ## 2. how does the data look like?

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 342          343         0       2
# 759          760         1       1
# 431          432         1       3
# 46            47         0       3
# 326          327         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 342                         Collander, Mr. Erik Gustaf    male  28.0      0
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0      0
# 431  Thorneycroft, Mrs. Percival (Florence Kate White)  female   NaN      1
# 46                                   Lennon, Mr. Denis    male   NaN      1
# 326                          Nysveen, Mr. Johan Hansen    male  61.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 342      0  248740  13.0000   NaN        S
# 759      0  110152  86.5000   B77        S
# 431      0  376564  16.1000   NaN        S
# 46       0  370371  15.5000   NaN        Q
# 326      0  345364   6.2375   NaN        S

# %% [markdown]
# ## 3. What is the data type of cols?

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %% [markdown]
# ## 4. Are there any missing values?

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## 5. How does the data look mathematically?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## 6. Are there duplicate values?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 7. How is the correlation between cols?

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.corr()
#
# File d:\ML\ml-env\Lib\site-packages\pandas\core\frame.py:13133, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13129         """  # noqa: E501
#   13130         data = self._get_numeric_data() if numeric_only else self
#   13131         cols = data.columns
#   13132         idx = cols.copy()
# > 13133         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13134
#   13135         if method == "pearson":
#   13136             correl = libalgos.nancorr(mat, minp=min_periods)
#
# File d:\ML\ml-env\Lib\site-packages\pandas\core\frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2077                [2, 4.5, Timestamp('2000-01-02 00:00:00')]], dtype=object)
#    2078         """
#    2079         if dtype is not None:
# ...

# %% [markdown]
# #### above error occur because in newer version of pandas df.corr() want to select all column as numeric but there are some col whicn is string

# %% [markdown]
# #### method to solve this probelm

# %%
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# ##### lets understand the output given

# %% [markdown]
# ##### here `df.corr()` is used to find the relation between the columns that is whcih column is co related to whcih column (-) value show negative dependencies that is inverserly proportional and (+) value show directly proportionality
