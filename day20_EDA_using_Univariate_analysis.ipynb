# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df=pd.read_csv('dataset/titanic-dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### now we first analyse categorical data

# %% [markdown]
# #### a. Countplot

# %%
sns.countplot(df['Survived'])
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# as we can see the above output cant be understand easily and even it is not correct beacuse the syntax we use to print the graph is very older doesnt work perfectly in new version of seanborn hence we use another version

# %%
sns.countplot(x='Survived', data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# also it can be print by following sytax

# %%
sns.countplot(x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# from above we can find the number of pepole survived

# %% [markdown]
# above daigram can be also be print using pandas

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(x=df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# if we want the percentage or exact numebr of people so we use piechart

# %%
df['Survived'].value_counts().plot(kind="pie")
# Out:
# <Axes: >

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: >

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f',labels=['not survived','survived'],title='survival_distrribution')
# Out:
# <Axes: title={'center': 'survival_distrribution'}>

# %% [markdown]
# ## 2. Numerical Data

# %% [markdown]
# ### a. Histogram

# %%
sns.histplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# we can increase the numberof bins

# %%
plt.hist(df['Age'],bins=50)
# Out:
# (array([24.,  6., 14.,  3.,  7.,  8.,  6.,  3.,  7., 22., 13., 51., 40.,
#         27., 46., 24., 36., 47., 27., 35., 17., 34., 29., 11., 27.,  8.,
#         18.,  9., 17., 18.,  6., 17.,  6.,  9.,  7.,  2.,  7.,  4.,  7.,
#          4.,  3.,  1.,  0.,  2.,  3.,  0.,  1.,  0.,  0.,  1.]),
#  array([ 0.42  ,  2.0116,  3.6032,  5.1948,  6.7864,  8.378 ,  9.9696,
#         11.5612, 13.1528, 14.7444, 16.336 , 17.9276, 19.5192, 21.1108,
#         22.7024, 24.294 , 25.8856, 27.4772, 29.0688, 30.6604, 32.252 ,
#         33.8436, 35.4352, 37.0268, 38.6184, 40.21  , 41.8016, 43.3932,
#         44.9848, 46.5764, 48.168 , 49.7596, 51.3512, 52.9428, 54.5344,
#         56.126 , 57.7176, 59.3092, 60.9008, 62.4924, 64.084 , 65.6756,
#         67.2672, 68.8588, 70.4504, 72.042 , 73.6336, 75.2252, 76.8168,
#         78.4084, 80.    ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# ### b. Distplot

# %% [markdown]
# distplot is depreicted in seaborn inseated of this new keyword `displot`

# %% [markdown]
# it is also a kind of histogra in this an extra probabilty distribution curve is given

# %%
sns.displot(x=df['Age'])

# %% [markdown]
# for(kde) means the histogram with kde(smooth density gramph)

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\Ravi Yadav\AppData\Local\Temp\ipykernel_9972\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
#  #### but when we use   ` displot `  the kde is not bydefault so we have to use `kde=True`

# %%
sns.displot(df['Age'])

# %%
sns.displot(df['Age'],kde=True)

# %% [markdown]
# now if  i have to remove this histogram

# %%
sns.displot(df['Age'],kde=True,hist=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 sns.displot(df['Age'],kde=True,hist=False)
#
# File d:\ML\ml-env\Lib\site-packages\seaborn\distributions.py:2193, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2190 if p.univariate:
#    2192     _assign_default_kwargs(hist_kws, p.plot_univariate_histogram, histplot)
# -> 2193     p.plot_univariate_histogram(**hist_kws)
#    2195 else:
#    2197     _assign_default_kwargs(hist_kws, p.plot_bivariate_histogram, histplot)
#
# ...

# %% [markdown]
# above syntax is not work in displot because the hist argument is no longer exists in new version but  ` distplot` which is older version does contain this hist argument

# %%
sns.distplot(df['Age'],hist=False)
# Out:
# C:\Users\Ravi Yadav\AppData\Local\Temp\ipykernel_9972\43512197.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],hist=False)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# in newer version of seaborn `displot` we can use like

# %%
sns.displot(df['Age'],kind='kde')

# %% [markdown]
# ### C. Boxplot

# %% [markdown]
# it is use for finding outlier in numerical column

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# as we see abvoe daata the points which is outside or left or right of two vertical thin line is called outlier

# %%
sns.boxplot(x=df['Fare'])
# Out:
# <Axes: xlabel='Fare'>

# %% [markdown]
# the boxplot also tells about the skiwnees of data
